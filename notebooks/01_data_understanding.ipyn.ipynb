# %%
import pandas as pd

df = pd.read_csv("../data/raw/SampleSuperstore.csv", sep=",", engine="c", converters={"Postal Code": pd.to_numeric})

# %%
df.shape  #O método shape apresenta a quantidade de linhas colunas presente no dataframe
# Out:
# (9994, 13)

# %%
df.shape[0]
# Out:
# 9994

# %%
df.shape[1]
# Out:
# 13

# %%
df.columns

# %% [markdown]
# #O método columns apresenta as colunas existentes no dataframe

# %%
df.dtypes

# %% [markdown]
# #O método dtypes, apresenta o tipo de cada coluna existente no dataframe

# %%
df.isna().sum()

# %%
df.info()  #O método apresenta as informações sobre os

# %%
df.isna().sum()

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df.duplicated()

# %% [markdown]
# # Primeiras conclusões
#
# A análise inicial identificou uma base com 9.994 linhas e 13 colunas.
# Não foram encontrados valores ausentes nas colunas analisadas.
#
# Foram identificados 17 registros duplicados. Esses registros ainda não
# foram removidos, pois é necessário investigar se representam duplicidades
# indevidas ou registros válidos.
#
# As colunas apresentam dados categóricos e numéricos, sendo necessário
# avaliar posteriormente se os tipos atualmente atribuídos são adequados
# para cada variável.
